# %%
#Imports and Path Setup
import os
from pathlib import Path
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage import io, filters, measure, color

# Define directories
root = "data"

imgs = list(Path(root).rglob("*Blue.tif"))
INPUT_DIR = "data/test_masking/"

OUTPUT_MASK_DIR = "output/experiments/generated_masks/"
os.makedirs(OUTPUT_MASK_DIR, exist_ok=True)
